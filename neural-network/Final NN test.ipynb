# %%
import time
from sklearn.neural_network import MLPClassifier
from sklearn import datasets, preprocessing
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd

# %%
bc = datasets.load_breast_cancer()

# %%
bc_df = pd.DataFrame(bc.data, columns=bc.feature_names)

# %%
bc_df['output'] = bc.target

# %%
corr = bc_df.corr()

# %%
corr.sort_values(by='output')[:2]
# Out:
#                       mean radius  mean texture  mean perimeter  mean area  \
# worst concave points     0.744214      0.295316        0.771241   0.722017
# worst perimeter          0.965137      0.358040        0.970387   0.959120
#
#                       mean smoothness  mean compactness  mean concavity  \
# worst concave points         0.503053          0.815573        0.861323
# worst perimeter              0.238853          0.590210        0.729565
#
#                       mean concave points  mean symmetry  \
# worst concave points             0.910155       0.430297
# worst perimeter                  0.855923       0.219169
#
#                       mean fractal dimension    ...     worst texture  \
# worst concave points                0.175325    ...          0.359755
# worst perimeter                    -0.205151    ...          0.365098
#
#                       worst perimeter  worst area  worst smoothness  \
# worst concave points         0.816322    0.747419          0.547691
# worst perimeter              1.000000    0.977578          0.236775
#
#                       worst compactness  worst concavity  \
# worst concave points           0.801080         0.855434
# worst perimeter                0.529408         0.618344
#
#                       worst concave points  worst symmetry  \
# worst concave points              1.000000        0.502528
# worst perimeter                   0.816322        0.269493
#
#                       worst fractal dimension    output
# worst concave points                 0.511114 -0.793566
# worst perimeter                      0.138957 -0.782914
#
# [2 rows x 31 columns]

# %%
print(bc.DESCR)
# Out:
# Breast Cancer Wisconsin (Diagnostic) Database
# =============================================
#
# Notes
# -----
# Data Set Characteristics:
#     :Number of Instances: 569
#
#     :Number of Attributes: 30 numeric, predictive attributes and the class
#
#     :Attribute Information:
#         - radius (mean of distances from center to points on the perimeter)
#         - texture (standard deviation of gray-scale values)
#         - perimeter
#         - area
#         - smoothness (local variation in radius lengths)
#         - compactness (perimeter^2 / area - 1.0)
#         - concavity (severity of concave portions of the contour)
#         - concave points (number of concave portions of the contour)
#         - symmetry
#         - fractal dimension ("coastline approximation" - 1)
#
#         The mean, standard error, and "worst" or largest (mean of the three
#         largest values) of these features were computed for each image,
#         resulting in 30 features.  For instance, field 3 is Mean Radius, field
#         13 is Radius SE, field 23 is Worst Radius.
#
#         - class:
#                 - WDBC-Malignant
#                 - WDBC-Benign
#
#     :Summary Statistics:
#
#     ===================================== ====== ======
#                                            Min    Max
#     ===================================== ====== ======
#     radius (mean):                        6.981  28.11
#     texture (mean):                       9.71   39.28
#     perimeter (mean):                     43.79  188.5
#     area (mean):                          143.5  2501.0
#     smoothness (mean):                    0.053  0.163
#     compactness (mean):                   0.019  0.345
#     concavity (mean):                     0.0    0.427
#     concave points (mean):                0.0    0.201
#     symmetry (mean):                      0.106  0.304
#     fractal dimension (mean):             0.05   0.097
#     radius (standard error):              0.112  2.873
#     texture (standard error):             0.36   4.885
#     perimeter (standard error):           0.757  21.98
#     area (standard error):                6.802  542.2
#     smoothness (standard error):          0.002  0.031
#     compactness (standard error):         0.002  0.135
#     concavity (standard error):           0.0    0.396
#     concave points (standard error):      0.0    0.053
#     symmetry (standard error):            0.008  0.079
#     fractal dimension (standard error):   0.001  0.03
#     radius (worst):                       7.93   36.04
#     texture (worst):                      12.02  49.54
#     perimeter (worst):                    50.41  251.2
#     area (worst):                         185.2  4254.0
#     smoothness (worst):                   0.071  0.223
#     compactness (worst):                  0.027  1.058
#     concavity (worst):                    0.0    1.252
#     concave points (worst):               0.0    0.291
#     symmetry (worst):                     0.156  0.664
#     fractal dimension (worst):            0.055  0.208
#     ===================================== ====== ======
#
#     :Missing Attribute Values: None
#
#     :Class Distribution: 212 - Malignant, 357 - Benign
#
#     :Creator:  Dr. William H. Wolberg, W. Nick Street, Olvi L. Mangasarian
#
#     :Donor: Nick Street
#
#     :Date: November, 1995
#
# This is a copy of UCI ML Breast Cancer Wisconsin (Diagnostic) datasets.
# https://goo.gl/U2Uwz2
#
# Features are computed from a digitized image of a fine needle
# aspirate (FNA) of a breast mass.  They describe
# characteristics of the cell nuclei present in the image.
#
# Separating plane described above was obtained using
# Multisurface Method-Tree (MSM-T) [K. P. Bennett, "Decision Tree
# Construction Via Linear Programming." Proceedings of the 4th
# Midwest Artificial Intelligence and Cognitive Science Society,
# pp. 97-101, 1992], a classification method which uses linear
# programming to construct a decision tree.  Relevant features
# were selected using an exhaustive search in the space of 1-4
# features and 1-3 separating planes.
#
# The actual linear program used to obtain the separating plane
# in the 3-dimensional space is that described in:
# [K. P. Bennett and O. L. Mangasarian: "Robust Linear
# Programming Discrimination of Two Linearly Inseparable Sets",
# Optimization Methods and Software 1, 1992, 23-34].
#
# This database is also available through the UW CS ftp server:
#
# ftp ftp.cs.wisc.edu
# cd math-prog/cpo-dataset/machine-learn/WDBC/
#
# References
# ----------
#    - W.N. Street, W.H. Wolberg and O.L. Mangasarian. Nuclear feature extraction
#      for breast tumor diagnosis. IS&T/SPIE 1993 International Symposium on
#      Electronic Imaging: Science and Technology, volume 1905, pages 861-870,
#      San Jose, CA, 1993.
#    - O.L. Mangasarian, W.N. Street and W.H. Wolberg. Breast cancer diagnosis and
#      prognosis via linear programming. Operations Research, 43(4), pages 570-577,
#      July-August 1995.
#    - W.H. Wolberg, W.N. Street, and O.L. Mangasarian. Machine learning techniques
#      to diagnose breast cancer from fine-needle aspirates. Cancer Letters 77 (1994)
#      163-171.

# %%
y1 = np.matrix([np.array(bc.target == 0),np.array(bc.target == 1)]).transpose()
y1.shape
# Out:
# (569, 2)

# %%
X = preprocessing.normalize(bc_df[['worst concave points','worst perimeter']],axis=1)  
# we only take the first two features.

# %%
X
# Out:
# array([[ 0.0014377 ,  0.99999897],
#        [ 0.00117128,  0.99999931],
#        [ 0.00159344,  0.99999873],
#        ...,
#        [ 0.00111918,  0.99999937],
#        [ 0.00143553,  0.99999897],
#        [ 0.        ,  1.        ]])

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y1, test_size=0.20, random_state=42)

# %%
clf = MLPClassifier(solver='adam', max_iter=1, warm_start=True,
                    hidden_layer_sizes=(3),random_state=42)

# %%
from rgb_nn import RGB_NN

# %%
conn = RGB_NN('saja')

# %%
c = None
for i in range(10):
    clf.fit(X_train, y_train)
    print(clf.score(X_test, y_test))
    print(conn.display_weights(clf))
# Out:
# 0.0
# val: -0.273635021605
# val: -0.273635021605
# val: 0.990464095545
# val: 0.990464095545
# val: 0.506632284665
# val: 0.506632284665
# val: 0.215069631034
# val: 0.215069631034
# val: -0.750622457449
# val: -0.750622457449
# val: -0.751786629897
# val: -0.751786629897
# val: 0.454295049441
# val: 0.454295049441
# val: -1.04826293436
# val: -1.04826293436
# val: 1.03227362593
# val: 1.03227362593
# val: 0.731332924727
# val: 0.731332924727
# val: -0.628453279569
# val: -0.628453279569
# val: -0.695243020754
# val: -0.695243020754
# val: -0.968190296587
# val: -0.968190296587
# val: 0.805254682634
# val: 0.805254682634
# val: 0.221531891337
# val: 0.221531891337
# val: -0.690905600054
# val: -0.690905600054
# val: -0.425903660297
# val: -0.425903660297
# {'leds': [{'led_num': 5, 'green': 0, 'red': 91, 'blue': 255}, {'led_num': 11, 'green': 0, 'red': 91, 'blue': 255}, {'led_num': 6, 'green': 0, 'red': 255, 'blue': 14}, {'led_num': 20, 'green': 0, 'red': 255, 'blue': 14}, {'led_num': 7, 'green': 244, 'red': 0, 'blue': 255}, {'led_num': 28, 'green': 244, 'red': 0, 'blue': 255}, {'led_num': 0, 'green': 255, 'red': 180, 'blue': 0}, {'led_num': 10, 'green': 255, 'red': 180, 'blue': 0}, {'led_num': 1, 'green': 255, 'red': 128, 'blue': 0}, {'led_num': 18, 'green': 255, 'red': 128, 'blue': 0}, {'led_num': 2, 'green': 255, 'red': 130, 'blue': 0}, {'led_num': 27, 'green': 255, 'red': 130, 'blue': 0}, {'led_num': 16, 'green': 255, 'red': 0, 'blue': 185}, {'led_num': 41, 'green': 255, 'red': 0, 'blue': 185}, {'led_num': 15, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 36, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 23, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 40, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 25, 'green': 0, 'red': 98, 'blue': 255}, {'led_num': 35, 'green': 0, 'red': 98, 'blue': 255}, {'led_num': 31, 'green': 255, 'red': 0, 'blue': 58}, {'led_num': 39, 'green': 255, 'red': 0, 'blue': 58}, {'led_num': 32, 'green': 255, 'red': 43, 'blue': 0}, {'led_num': 34, 'green': 255, 'red': 43, 'blue': 0}, {'led_num': 13, 'green': 48, 'red': 255, 'blue': 0}, {'led_num': 14, 'green': 48, 'red': 255, 'blue': 0}, {'led_num': 21, 'green': 0, 'red': 212, 'blue': 255}, {'led_num': 22, 'green': 0, 'red': 212, 'blue': 255}, {'led_num': 29, 'green': 255, 'red': 171, 'blue': 0}, {'led_num': 30, 'green': 255, 'red': 171, 'blue': 0}, {'led_num': 42, 'green': 255, 'red': 37, 'blue': 0}, {'led_num': 43, 'green': 255, 'red': 37, 'blue': 0}, {'led_num': 37, 'green': 141, 'red': 0, 'blue': 255}, {'led_num': 38, 'green': 141, 'red': 0, 'blue': 255}]}
# 0.0
# val: -0.272404145349
# val: -0.272404145349
# val: 0.993459293503
# val: 0.993459293503
# val: 0.504993433137
# val: 0.504993433137
# val: 0.213992478176
# val: 0.213992478176
# val: -0.747623857663
# val: -0.747623857663
# val: -0.749896547716
# val: -0.749896547716
# val: 0.452728207705
# val: 0.452728207705
# val: -1.04618020511
# val: -1.04618020511
# val: 1.03523222315
# val: 1.03523222315
# val: 0.734336779073
# val: 0.734336779073
# val: -0.626674925283
# val: -0.626674925283
# val: -0.693401117732
# val: -0.693401117732
# val: -0.968190296587
# val: -0.968190296587
# val: 0.808253282206
# val: 0.808253282206
# val: 0.221531891337
# val: 0.221531891337
# val: -0.68796400937
# val: -0.68796400937
# val: -0.422901797364
# val: -0.422901797364
# {'leds': [{'led_num': 5, 'green': 0, 'red': 93, 'blue': 255}, {'led_num': 11, 'green': 0, 'red': 93, 'blue': 255}, {'led_num': 6, 'green': 0, 'red': 255, 'blue': 10}, {'led_num': 20, 'green': 0, 'red': 255, 'blue': 10}, {'led_num': 7, 'green': 247, 'red': 0, 'blue': 255}, {'led_num': 28, 'green': 247, 'red': 0, 'blue': 255}, {'led_num': 0, 'green': 255, 'red': 182, 'blue': 0}, {'led_num': 10, 'green': 255, 'red': 182, 'blue': 0}, {'led_num': 1, 'green': 255, 'red': 123, 'blue': 0}, {'led_num': 18, 'green': 255, 'red': 123, 'blue': 0}, {'led_num': 2, 'green': 255, 'red': 127, 'blue': 0}, {'led_num': 27, 'green': 255, 'red': 127, 'blue': 0}, {'led_num': 16, 'green': 255, 'red': 0, 'blue': 182}, {'led_num': 41, 'green': 255, 'red': 0, 'blue': 182}, {'led_num': 15, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 36, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 23, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 40, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 25, 'green': 0, 'red': 103, 'blue': 255}, {'led_num': 35, 'green': 0, 'red': 103, 'blue': 255}, {'led_num': 31, 'green': 255, 'red': 0, 'blue': 61}, {'led_num': 39, 'green': 255, 'red': 0, 'blue': 61}, {'led_num': 32, 'green': 255, 'red': 40, 'blue': 0}, {'led_num': 34, 'green': 255, 'red': 40, 'blue': 0}, {'led_num': 13, 'green': 48, 'red': 255, 'blue': 0}, {'led_num': 14, 'green': 48, 'red': 255, 'blue': 0}, {'led_num': 21, 'green': 0, 'red': 216, 'blue': 255}, {'led_num': 22, 'green': 0, 'red': 216, 'blue': 255}, {'led_num': 29, 'green': 255, 'red': 171, 'blue': 0}, {'led_num': 30, 'green': 255, 'red': 171, 'blue': 0}, {'led_num': 42, 'green': 255, 'red': 32, 'blue': 0}, {'led_num': 43, 'green': 255, 'red': 32, 'blue': 0}, {'led_num': 37, 'green': 137, 'red': 0, 'blue': 255}, {'led_num': 38, 'green': 137, 'red': 0, 'blue': 255}]}
# 0.0
# val: -0.271176203556
# val: -0.271176203556
# val: 0.996454444192
# val: 0.996454444192
# val: 0.503356710828
# val: 0.503356710828
# val: 0.212918453658
# val: 0.212918453658
# val: -0.744625289143
# val: -0.744625289143
# val: -0.748008001576
# val: -0.748008001576
# val: 0.45116365769
# val: 0.45116365769
# val: -1.04409856225
# val: -1.04409856225
# val: 1.03818231378
# val: 1.03818231378
# val: 0.737340497316
# val: 0.737340497316
# val: -0.624898373392
# val: -0.624898373392
# val: -0.691560865648
# val: -0.691560865648
# val: -0.968190296587
# val: -0.968190296587
# val: 0.811251850509
# val: 0.811251850509
# val: 0.221531891337
# val: 0.221531891337
# val: -0.685031818171
# val: -0.685031818171
# val: -0.419899922199
# val: -0.419899922199
# {'leds': [{'led_num': 5, 'green': 0, 'red': 95, 'blue': 255}, {'led_num': 11, 'green': 0, 'red': 95, 'blue': 255}, {'led_num': 6, 'green': 0, 'red': 255, 'blue': 5}, {'led_num': 20, 'green': 0, 'red': 255, 'blue': 5}, {'led_num': 7, 'green': 249, 'red': 0, 'blue': 255}, {'led_num': 28, 'green': 249, 'red': 0, 'blue': 255}, {'led_num': 0, 'green': 255, 'red': 184, 'blue': 0}, {'led_num': 10, 'green': 255, 'red': 184, 'blue': 0}, {'led_num': 1, 'green': 255, 'red': 119, 'blue': 0}, {'led_num': 18, 'green': 255, 'red': 119, 'blue': 0}, {'led_num': 2, 'green': 255, 'red': 124, 'blue': 0}, {'led_num': 27, 'green': 255, 'red': 124, 'blue': 0}, {'led_num': 16, 'green': 255, 'red': 0, 'blue': 180}, {'led_num': 41, 'green': 255, 'red': 0, 'blue': 180}, {'led_num': 15, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 36, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 23, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 40, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 25, 'green': 0, 'red': 108, 'blue': 255}, {'led_num': 35, 'green': 0, 'red': 108, 'blue': 255}, {'led_num': 31, 'green': 255, 'red': 0, 'blue': 63}, {'led_num': 39, 'green': 255, 'red': 0, 'blue': 63}, {'led_num': 32, 'green': 255, 'red': 38, 'blue': 0}, {'led_num': 34, 'green': 255, 'red': 38, 'blue': 0}, {'led_num': 13, 'green': 48, 'red': 255, 'blue': 0}, {'led_num': 14, 'green': 48, 'red': 255, 'blue': 0}, {'led_num': 21, 'green': 0, 'red': 221, 'blue': 255}, {'led_num': 22, 'green': 0, 'red': 221, 'blue': 255}, {'led_num': 29, 'green': 255, 'red': 171, 'blue': 0}, {'led_num': 30, 'green': 255, 'red': 171, 'blue': 0}, {'led_num': 42, 'green': 255, 'red': 28, 'blue': 0}, {'led_num': 43, 'green': 255, 'red': 28, 'blue': 0}, {'led_num': 37, 'green': 132, 'red': 0, 'blue': 255}, {'led_num': 38, 'green': 132, 'red': 0, 'blue': 255}]}
# 0.0
# val: -0.269951200656
# val: -0.269951200656
# val: 0.999449545682
# val: 0.999449545682
# val: 0.501722122621
# val: 0.501722122621
# val: 0.211847560539
# val: 0.211847560539
# val: -0.741626753285
# val: -0.741626753285
# val: -0.746120995135
# val: -0.746120995135
# val: 0.44960140447
# val: 0.44960140447
# val: -1.04201800826
# val: -1.04201800826
# val: 1.04112158769
# val: 1.04112158769
# val: 0.74034409802
# val: 0.74034409802
# val: -0.62312362818
# val: -0.62312362818
# val: -0.68972226844
# val: -0.68972226844
# val: -0.968190296587
# val: -0.968190296587
# val: 0.814250386147
# val: 0.814250386147
# val: 0.221531891337
# val: 0.221531891337
# val: -0.682111984789
# val: -0.682111984789
# val: -0.416898034539
# val: -0.416898034539
# {'leds': [{'led_num': 5, 'green': 0, 'red': 96, 'blue': 255}, {'led_num': 11, 'green': 0, 'red': 96, 'blue': 255}, {'led_num': 6, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 20, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 7, 'green': 252, 'red': 0, 'blue': 255}, {'led_num': 28, 'green': 252, 'red': 0, 'blue': 255}, {'led_num': 0, 'green': 255, 'red': 185, 'blue': 0}, {'led_num': 10, 'green': 255, 'red': 185, 'blue': 0}, {'led_num': 1, 'green': 255, 'red': 114, 'blue': 0}, {'led_num': 18, 'green': 255, 'red': 114, 'blue': 0}, {'led_num': 2, 'green': 255, 'red': 121, 'blue': 0}, {'led_num': 27, 'green': 255, 'red': 121, 'blue': 0}, {'led_num': 16, 'green': 255, 'red': 0, 'blue': 177}, {'led_num': 41, 'green': 255, 'red': 0, 'blue': 177}, {'led_num': 15, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 36, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 23, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 40, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 25, 'green': 0, 'red': 112, 'blue': 255}, {'led_num': 35, 'green': 0, 'red': 112, 'blue': 255}, {'led_num': 31, 'green': 255, 'red': 0, 'blue': 66}, {'led_num': 39, 'green': 255, 'red': 0, 'blue': 66}, {'led_num': 32, 'green': 255, 'red': 35, 'blue': 0}, {'led_num': 34, 'green': 255, 'red': 35, 'blue': 0}, {'led_num': 13, 'green': 48, 'red': 255, 'blue': 0}, {'led_num': 14, 'green': 48, 'red': 255, 'blue': 0}, {'led_num': 21, 'green': 0, 'red': 225, 'blue': 255}, {'led_num': 22, 'green': 0, 'red': 225, 'blue': 255}, {'led_num': 29, 'green': 255, 'red': 171, 'blue': 0}, {'led_num': 30, 'green': 255, 'red': 171, 'blue': 0}, {'led_num': 42, 'green': 255, 'red': 23, 'blue': 0}, {'led_num': 43, 'green': 255, 'red': 23, 'blue': 0}, {'led_num': 37, 'green': 127, 'red': 0, 'blue': 255}, {'led_num': 38, 'green': 127, 'red': 0, 'blue': 255}]}
# 0.0
# val: -0.268729141061
# val: -0.268729141061
# val: 1.00244459594
# val: 1.00244459594
# val: 0.500089673404
# val: 0.500089673404
# val: 0.210779801844
# val: 0.210779801844
# val: -0.738628251549
# val: -0.738628251549
# val: -0.74423553206
# val: -0.74423553206
# val: 0.448041453125
# val: 0.448041453125
# val: -1.03993854558
# val: -1.03993854558
# val: 1.04404657757
# val: 1.04404657757
# val: 0.743347596999
# val: 0.743347596999
# val: -0.62135069394
# val: -0.62135069394
# val: -0.687885330058
# val: -0.687885330058
# val: -0.968190296587
# val: -0.968190296587
# val: 0.817248887659
# val: 0.817248887659
# val: 0.221531891337
# val: 0.221531891337
# val: -0.679208900353
# val: -0.679208900353
# val: -0.413896134112
# val: -0.413896134112
# {'leds': [{'led_num': 5, 'green': 0, 'red': 98, 'blue': 255}, {'led_num': 11, 'green': 0, 'red': 98, 'blue': 255}, {'led_num': 6, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 20, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 7, 'green': 254, 'red': 0, 'blue': 255}, {'led_num': 28, 'green': 254, 'red': 0, 'blue': 255}, {'led_num': 0, 'green': 255, 'red': 187, 'blue': 0}, {'led_num': 10, 'green': 255, 'red': 187, 'blue': 0}, {'led_num': 1, 'green': 255, 'red': 110, 'blue': 0}, {'led_num': 18, 'green': 255, 'red': 110, 'blue': 0}, {'led_num': 2, 'green': 255, 'red': 118, 'blue': 0}, {'led_num': 27, 'green': 255, 'red': 118, 'blue': 0}, {'led_num': 16, 'green': 255, 'red': 0, 'blue': 175}, {'led_num': 41, 'green': 255, 'red': 0, 'blue': 175}, {'led_num': 15, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 36, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 23, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 40, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 25, 'green': 0, 'red': 117, 'blue': 255}, {'led_num': 35, 'green': 0, 'red': 117, 'blue': 255}, {'led_num': 31, 'green': 255, 'red': 0, 'blue': 69}, {'led_num': 39, 'green': 255, 'red': 0, 'blue': 69}, {'led_num': 32, 'green': 255, 'red': 32, 'blue': 0}, {'led_num': 34, 'green': 255, 'red': 32, 'blue': 0}, {'led_num': 13, 'green': 48, 'red': 255, 'blue': 0}, {'led_num': 14, 'green': 48, 'red': 255, 'blue': 0}, {'led_num': 21, 'green': 0, 'red': 230, 'blue': 255}, {'led_num': 22, 'green': 0, 'red': 230, 'blue': 255}, {'led_num': 29, 'green': 255, 'red': 171, 'blue': 0}, {'led_num': 30, 'green': 255, 'red': 171, 'blue': 0}, {'led_num': 42, 'green': 255, 'red': 19, 'blue': 0}, {'led_num': 43, 'green': 255, 'red': 19, 'blue': 0}, {'led_num': 37, 'green': 123, 'red': 0, 'blue': 255}, {'led_num': 38, 'green': 123, 'red': 0, 'blue': 255}]}
# 0.0
# val: -0.267510029161
# val: -0.267510029161
# val: 1.00543959284
# val: 1.00543959284
# val: 0.498459368072
# val: 0.498459368072
# val: 0.20971518056
# val: 0.20971518056
# val: -0.735629785452
# val: -0.735629785452
# val: -0.742351616029
# val: -0.742351616029
# val: 0.446483808736
# val: 0.446483808736
# val: -1.03786017669
# val: -1.03786017669
# val: 1.04695191543
# val: 1.04695191543
# val: 0.746351007678
# val: 0.746351007678
# val: -0.619579574975
# val: -0.619579574975
# val: -0.686050054462
# val: -0.686050054462
# val: -0.968190296587
# val: -0.968190296587
# val: 0.820247353528
# val: 0.820247353528
# val: 0.221531891337
# val: 0.221531891337
# val: -0.676329362017
# val: -0.676329362017
# val: -0.410894220639
# val: -0.410894220639
# {'leds': [{'led_num': 5, 'green': 0, 'red': 100, 'blue': 255}, {'led_num': 11, 'green': 0, 'red': 100, 'blue': 255}, {'led_num': 6, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 20, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 7, 'green': 255, 'red': 0, 'blue': 252}, {'led_num': 28, 'green': 255, 'red': 0, 'blue': 252}, {'led_num': 0, 'green': 255, 'red': 189, 'blue': 0}, {'led_num': 10, 'green': 255, 'red': 189, 'blue': 0}, {'led_num': 1, 'green': 255, 'red': 105, 'blue': 0}, {'led_num': 18, 'green': 255, 'red': 105, 'blue': 0}, {'led_num': 2, 'green': 255, 'red': 115, 'blue': 0}, {'led_num': 27, 'green': 255, 'red': 115, 'blue': 0}, {'led_num': 16, 'green': 255, 'red': 0, 'blue': 173}, {'led_num': 41, 'green': 255, 'red': 0, 'blue': 173}, {'led_num': 15, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 36, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 23, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 40, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 25, 'green': 0, 'red': 121, 'blue': 255}, {'led_num': 35, 'green': 0, 'red': 121, 'blue': 255}, {'led_num': 31, 'green': 255, 'red': 0, 'blue': 72}, {'led_num': 39, 'green': 255, 'red': 0, 'blue': 72}, {'led_num': 32, 'green': 255, 'red': 29, 'blue': 0}, {'led_num': 34, 'green': 255, 'red': 29, 'blue': 0}, {'led_num': 13, 'green': 48, 'red': 255, 'blue': 0}, {'led_num': 14, 'green': 48, 'red': 255, 'blue': 0}, {'led_num': 21, 'green': 0, 'red': 234, 'blue': 255}, {'led_num': 22, 'green': 0, 'red': 234, 'blue': 255}, {'led_num': 29, 'green': 255, 'red': 171, 'blue': 0}, {'led_num': 30, 'green': 255, 'red': 171, 'blue': 0}, {'led_num': 42, 'green': 255, 'red': 14, 'blue': 0}, {'led_num': 43, 'green': 255, 'red': 14, 'blue': 0}, {'led_num': 37, 'green': 118, 'red': 0, 'blue': 255}, {'led_num': 38, 'green': 118, 'red': 0, 'blue': 255}]}
# 0.0
# val: -0.266293869326
# val: -0.266293869326
# val: 1.00843453414
# val: 1.00843453414
# val: 0.496831211528
# val: 0.496831211528
# val: 0.208653699638
# val: 0.208653699638
# val: -0.73263135654
# val: -0.73263135654
# val: -0.740469250726
# val: -0.740469250726
# val: 0.444928476393
# val: 0.444928476393
# val: -1.03578290406
# val: -1.03578290406
# val: 1.04982893361
# val: 1.04982893361
# val: 0.749354341486
# val: 0.749354341486
# val: -0.617810275598
# val: -0.617810275598
# val: -0.684216445617
# val: -0.684216445617
# val: -0.968190296587
# val: -0.968190296587
# val: 0.82324578221
# val: 0.82324578221
# val: 0.221531891337
# val: 0.221531891337
# val: -0.673484417891
# val: -0.673484417891
# val: -0.407892293833
# val: -0.407892293833
# {'leds': [{'led_num': 5, 'green': 0, 'red': 102, 'blue': 255}, {'led_num': 11, 'green': 0, 'red': 102, 'blue': 255}, {'led_num': 6, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 20, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 7, 'green': 255, 'red': 0, 'blue': 250}, {'led_num': 28, 'green': 255, 'red': 0, 'blue': 250}, {'led_num': 0, 'green': 255, 'red': 190, 'blue': 0}, {'led_num': 10, 'green': 255, 'red': 190, 'blue': 0}, {'led_num': 1, 'green': 255, 'red': 100, 'blue': 0}, {'led_num': 18, 'green': 255, 'red': 100, 'blue': 0}, {'led_num': 2, 'green': 255, 'red': 112, 'blue': 0}, {'led_num': 27, 'green': 255, 'red': 112, 'blue': 0}, {'led_num': 16, 'green': 255, 'red': 0, 'blue': 170}, {'led_num': 41, 'green': 255, 'red': 0, 'blue': 170}, {'led_num': 15, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 36, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 23, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 40, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 25, 'green': 0, 'red': 126, 'blue': 255}, {'led_num': 35, 'green': 0, 'red': 126, 'blue': 255}, {'led_num': 31, 'green': 255, 'red': 0, 'blue': 74}, {'led_num': 39, 'green': 255, 'red': 0, 'blue': 74}, {'led_num': 32, 'green': 255, 'red': 26, 'blue': 0}, {'led_num': 34, 'green': 255, 'red': 26, 'blue': 0}, {'led_num': 13, 'green': 48, 'red': 255, 'blue': 0}, {'led_num': 14, 'green': 48, 'red': 255, 'blue': 0}, {'led_num': 21, 'green': 0, 'red': 239, 'blue': 255}, {'led_num': 22, 'green': 0, 'red': 239, 'blue': 255}, {'led_num': 29, 'green': 255, 'red': 171, 'blue': 0}, {'led_num': 30, 'green': 255, 'red': 171, 'blue': 0}, {'led_num': 42, 'green': 255, 'red': 10, 'blue': 0}, {'led_num': 43, 'green': 255, 'red': 10, 'blue': 0}, {'led_num': 37, 'green': 114, 'red': 0, 'blue': 255}, {'led_num': 38, 'green': 114, 'red': 0, 'blue': 255}]}
# 0.0
# val: -0.26508066591
# val: -0.26508066591
# val: 1.01142941753
# val: 1.01142941753
# val: 0.495205208681
# val: 0.495205208681
# val: 0.207595361993
# val: 0.207595361993
# val: -0.729632966329
# val: -0.729632966329
# val: -0.738588439847
# val: -0.738588439847
# val: 0.443375461187
# val: 0.443375461187
# val: -1.03370673018
# val: -1.03370673018
# val: 1.05266289829
# val: 1.05266289829
# val: 0.752357608197
# val: 0.752357608197
# val: -0.616042800128
# val: -0.616042800128
# val: -0.682384507503
# val: -0.682384507503
# val: -0.968190296587
# val: -0.968190296587
# val: 0.826244172186
# val: 0.826244172186
# val: 0.221531891337
# val: 0.221531891337
# val: -0.67069304213
# val: -0.67069304213
# val: -0.404890353397
# val: -0.404890353397
# {'leds': [{'led_num': 5, 'green': 0, 'red': 104, 'blue': 255}, {'led_num': 11, 'green': 0, 'red': 104, 'blue': 255}, {'led_num': 6, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 20, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 7, 'green': 255, 'red': 0, 'blue': 247}, {'led_num': 28, 'green': 255, 'red': 0, 'blue': 247}, {'led_num': 0, 'green': 255, 'red': 192, 'blue': 0}, {'led_num': 10, 'green': 255, 'red': 192, 'blue': 0}, {'led_num': 1, 'green': 255, 'red': 96, 'blue': 0}, {'led_num': 18, 'green': 255, 'red': 96, 'blue': 0}, {'led_num': 2, 'green': 255, 'red': 110, 'blue': 0}, {'led_num': 27, 'green': 255, 'red': 110, 'blue': 0}, {'led_num': 16, 'green': 255, 'red': 0, 'blue': 168}, {'led_num': 41, 'green': 255, 'red': 0, 'blue': 168}, {'led_num': 15, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 36, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 23, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 40, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 25, 'green': 0, 'red': 131, 'blue': 255}, {'led_num': 35, 'green': 0, 'red': 131, 'blue': 255}, {'led_num': 31, 'green': 255, 'red': 0, 'blue': 77}, {'led_num': 39, 'green': 255, 'red': 0, 'blue': 77}, {'led_num': 32, 'green': 255, 'red': 24, 'blue': 0}, {'led_num': 34, 'green': 255, 'red': 24, 'blue': 0}, {'led_num': 13, 'green': 48, 'red': 255, 'blue': 0}, {'led_num': 14, 'green': 48, 'red': 255, 'blue': 0}, {'led_num': 21, 'green': 0, 'red': 244, 'blue': 255}, {'led_num': 22, 'green': 0, 'red': 244, 'blue': 255}, {'led_num': 29, 'green': 255, 'red': 171, 'blue': 0}, {'led_num': 30, 'green': 255, 'red': 171, 'blue': 0}, {'led_num': 42, 'green': 255, 'red': 6, 'blue': 0}, {'led_num': 43, 'green': 255, 'red': 6, 'blue': 0}, {'led_num': 37, 'green': 109, 'red': 0, 'blue': 255}, {'led_num': 38, 'green': 109, 'red': 0, 'blue': 255}]}
# 0.0
# val: -0.263870423241
# val: -0.263870423241
# val: 1.01442424067
# val: 1.01442424067
# val: 0.493581364446
# val: 0.493581364446
# val: 0.206540170503
# val: 0.206540170503
# val: -0.726634616175
# val: -0.726634616175
# val: -0.736709187097
# val: -0.736709187097
# val: 0.441824768215
# val: 0.441824768215
# val: -1.03163165754
# val: -1.03163165754
# val: 1.05542730174
# val: 1.05542730174
# val: 0.755360816224
# val: 0.755360816224
# val: -0.614277152897
# val: -0.614277152897
# val: -0.680554244105
# val: -0.680554244105
# val: -0.968190296587
# val: -0.968190296587
# val: 0.829242522101
# val: 0.829242522101
# val: 0.221531891337
# val: 0.221531891337
# val: -0.667989695309
# val: -0.667989695309
# val: -0.401888399028
# val: -0.401888399028
# {'leds': [{'led_num': 5, 'green': 0, 'red': 106, 'blue': 255}, {'led_num': 11, 'green': 0, 'red': 106, 'blue': 255}, {'led_num': 6, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 20, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 7, 'green': 255, 'red': 0, 'blue': 245}, {'led_num': 28, 'green': 255, 'red': 0, 'blue': 245}, {'led_num': 0, 'green': 255, 'red': 193, 'blue': 0}, {'led_num': 10, 'green': 255, 'red': 193, 'blue': 0}, {'led_num': 1, 'green': 255, 'red': 91, 'blue': 0}, {'led_num': 18, 'green': 255, 'red': 91, 'blue': 0}, {'led_num': 2, 'green': 255, 'red': 107, 'blue': 0}, {'led_num': 27, 'green': 255, 'red': 107, 'blue': 0}, {'led_num': 16, 'green': 255, 'red': 0, 'blue': 165}, {'led_num': 41, 'green': 255, 'red': 0, 'blue': 165}, {'led_num': 15, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 36, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 23, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 40, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 25, 'green': 0, 'red': 135, 'blue': 255}, {'led_num': 35, 'green': 0, 'red': 135, 'blue': 255}, {'led_num': 31, 'green': 255, 'red': 0, 'blue': 80}, {'led_num': 39, 'green': 255, 'red': 0, 'blue': 80}, {'led_num': 32, 'green': 255, 'red': 21, 'blue': 0}, {'led_num': 34, 'green': 255, 'red': 21, 'blue': 0}, {'led_num': 13, 'green': 48, 'red': 255, 'blue': 0}, {'led_num': 14, 'green': 48, 'red': 255, 'blue': 0}, {'led_num': 21, 'green': 0, 'red': 248, 'blue': 255}, {'led_num': 22, 'green': 0, 'red': 248, 'blue': 255}, {'led_num': 29, 'green': 255, 'red': 171, 'blue': 0}, {'led_num': 30, 'green': 255, 'red': 171, 'blue': 0}, {'led_num': 42, 'green': 255, 'red': 2, 'blue': 0}, {'led_num': 43, 'green': 255, 'red': 2, 'blue': 0}, {'led_num': 37, 'green': 104, 'red': 0, 'blue': 255}, {'led_num': 38, 'green': 104, 'red': 0, 'blue': 255}]}
# 0.0
# val: -0.262663145631
# val: -0.262663145631
# val: 1.01741900134
# val: 1.01741900134
# val: 0.491959683748
# val: 0.491959683748
# val: 0.205488128007
# val: 0.205488128007
# val: -0.723636306969
# val: -0.723636306969
# val: -0.734831496188
# val: -0.734831496188
# val: 0.440276402577
# val: 0.440276402577
# val: -1.02955768862
# val: -1.02955768862
# val: 1.05807207941
# val: 1.05807207941
# val: 0.758363972851
# val: 0.758363972851
# val: -0.612513338244
# val: -0.612513338244
# val: -0.67872565942
# val: -0.67872565942
# val: -0.968190296587
# val: -0.968190296587
# val: 0.832240831063
# val: 0.832240831063
# val: 0.221531891337
# val: 0.221531891337
# val: -0.66543930963
# val: -0.66543930963
# val: -0.398886430412
# val: -0.398886430412
# {'leds': [{'led_num': 5, 'green': 0, 'red': 108, 'blue': 255}, {'led_num': 11, 'green': 0, 'red': 108, 'blue': 255}, {'led_num': 6, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 20, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 7, 'green': 255, 'red': 0, 'blue': 242}, {'led_num': 28, 'green': 255, 'red': 0, 'blue': 242}, {'led_num': 0, 'green': 255, 'red': 195, 'blue': 0}, {'led_num': 10, 'green': 255, 'red': 195, 'blue': 0}, {'led_num': 1, 'green': 255, 'red': 87, 'blue': 0}, {'led_num': 18, 'green': 255, 'red': 87, 'blue': 0}, {'led_num': 2, 'green': 255, 'red': 104, 'blue': 0}, {'led_num': 27, 'green': 255, 'red': 104, 'blue': 0}, {'led_num': 16, 'green': 255, 'red': 0, 'blue': 163}, {'led_num': 41, 'green': 255, 'red': 0, 'blue': 163}, {'led_num': 15, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 36, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 23, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 40, 'green': 0, 'red': 255, 'blue': 0}, {'led_num': 25, 'green': 0, 'red': 140, 'blue': 255}, {'led_num': 35, 'green': 0, 'red': 140, 'blue': 255}, {'led_num': 31, 'green': 255, 'red': 0, 'blue': 82}, {'led_num': 39, 'green': 255, 'red': 0, 'blue': 82}, {'led_num': 32, 'green': 255, 'red': 18, 'blue': 0}, {'led_num': 34, 'green': 255, 'red': 18, 'blue': 0}, {'led_num': 13, 'green': 48, 'red': 255, 'blue': 0}, {'led_num': 14, 'green': 48, 'red': 255, 'blue': 0}, {'led_num': 21, 'green': 0, 'red': 253, 'blue': 255}, {'led_num': 22, 'green': 0, 'red': 253, 'blue': 255}, {'led_num': 29, 'green': 255, 'red': 171, 'blue': 0}, {'led_num': 30, 'green': 255, 'red': 171, 'blue': 0}, {'led_num': 42, 'green': 255, 'red': 0, 'blue': 1}, {'led_num': 43, 'green': 255, 'red': 0, 'blue': 1}, {'led_num': 37, 'green': 100, 'red': 0, 'blue': 255}, {'led_num': 38, 'green': 100, 'red': 0, 'blue': 255}]}
# /Users/zackakil/anaconda/envs/dev/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)

# %%
clf.coefs_
# Out:
# [array([[-0.26266315,  1.017419  ,  0.49195968],
#         [ 0.20548813, -0.72363631, -0.7348315 ]]),
#  array([[ 0.4402764 , -1.02955769],
#         [ 1.05807208,  0.75836397],
#         [-0.61251334, -0.67872566]])]

# %%
X_train
# Out:
# array([[  2.67174619e-03,   9.99996431e-01],
#        [  1.64475698e-03,   9.99998647e-01],
#        [  7.75575312e-04,   9.99999699e-01],
#        [  7.86868184e-04,   9.99999690e-01],
#        [  3.69166880e-04,   9.99999932e-01],
#        [  1.37953132e-03,   9.99999048e-01],
#        [  1.00393263e-03,   9.99999496e-01],
#        [  1.06042728e-03,   9.99999438e-01],
#        [  9.48151999e-04,   9.99999551e-01],
#        [  1.00498392e-03,   9.99999495e-01],
#        [  1.31751471e-03,   9.99999132e-01],
#        [  1.35552789e-03,   9.99999081e-01],
#        [  1.59480521e-03,   9.99998728e-01],
#        [  9.25507504e-04,   9.99999572e-01],
#        [  7.45200305e-04,   9.99999722e-01],
#        [  1.10594728e-03,   9.99999388e-01],
#        [  1.43770166e-03,   9.99998967e-01],
#        [  1.83061076e-03,   9.99998324e-01],
#        [  7.11720047e-04,   9.99999747e-01],
#        [  7.09465961e-04,   9.99999748e-01],
#        [  9.10289860e-04,   9.99999586e-01],
#        [  1.91286620e-03,   9.99998170e-01],
#        [  1.49285768e-03,   9.99998886e-01],
#        [  9.14223288e-04,   9.99999582e-01],
#        [  1.27696422e-03,   9.99999185e-01],
#        [  1.55894637e-03,   9.99998785e-01],
#        [  9.29688076e-04,   9.99999568e-01],
#        [  1.27837155e-03,   9.99999183e-01],
#        [  9.14378970e-04,   9.99999582e-01],
#        [  6.13958694e-04,   9.99999812e-01],
#        [  1.81023534e-03,   9.99998362e-01],
#        [  6.86117583e-04,   9.99999765e-01],
#        [  1.35488184e-03,   9.99999082e-01],
#        [  1.21288603e-03,   9.99999264e-01],
#        [  1.07732802e-03,   9.99999420e-01],
#        [  3.38304373e-04,   9.99999943e-01],
#        [  1.29991394e-03,   9.99999155e-01],
#        [  5.69848915e-04,   9.99999838e-01],
#        [  4.47782002e-04,   9.99999900e-01],
#        [  8.10636069e-04,   9.99999671e-01],
#        [  2.60962156e-04,   9.99999966e-01],
#        [  1.40715528e-03,   9.99999010e-01],
#        [  1.07936445e-03,   9.99999417e-01],
#        [  0.00000000e+00,   1.00000000e+00],
#        [  7.79178649e-04,   9.99999696e-01],
#        [  5.43913840e-04,   9.99999852e-01],
#        [  0.00000000e+00,   1.00000000e+00],
#        [  1.13964838e-03,   9.99999351e-01],
#        [  1.38214616e-04,   9.99999990e-01],
#        [  1.04077679e-03,   9.99999458e-01],
#        [  5.97184271e-04,   9.99999822e-01],
#        [  1.14359341e-03,   9.99999346e-01],
#        [  6.86587909e-04,   9.99999764e-01],
#        [  1.01955254e-03,   9.99999480e-01],
#        [  1.35623250e-03,   9.99999080e-01],
#        [  1.43490418e-03,   9.99998971e-01],
#        [  1.48666502e-03,   9.99998895e-01],
#        [  6.19302279e-04,   9.99999808e-01],
#        [  9.75975185e-04,   9.99999524e-01],
#        [  9.71077544e-04,   9.99999529e-01],
#        [  9.06838081e-04,   9.99999589e-01],
#        [  7.35191439e-04,   9.99999730e-01],
#        [  6.42355562e-04,   9.99999794e-01],
#        [  1.20752977e-03,   9.99999271e-01],
#        [  6.22790577e-04,   9.99999806e-01],
#        [  1.03685686e-03,   9.99999462e-01],
#        [  1.29135968e-03,   9.99999166e-01],
#        [  1.02245156e-03,   9.99999477e-01],
#        [  1.62840975e-03,   9.99998674e-01],
#        [  9.42635240e-04,   9.99999556e-01],
#        [  1.13592823e-03,   9.99999355e-01],
#        [  1.40687022e-03,   9.99999010e-01],
#        [  1.06167341e-03,   9.99999436e-01],
#        [  1.29187455e-03,   9.99999166e-01],
#        [  1.46159844e-03,   9.99998932e-01],
#        [  6.11262573e-04,   9.99999813e-01],
#        [  1.22927597e-03,   9.99999244e-01],
#        [  1.13445305e-03,   9.99999357e-01],
#        [  8.65198814e-04,   9.99999626e-01],
#        [  0.00000000e+00,   1.00000000e+00],
#        [  7.82317833e-04,   9.99999694e-01],
#        [  1.00310027e-03,   9.99999497e-01],
#        [  1.29494841e-03,   9.99999162e-01],
#        [  1.09856946e-03,   9.99999397e-01],
#        [  1.67322600e-03,   9.99998600e-01],
#        [  6.87708712e-04,   9.99999764e-01],
#        [  5.60559218e-04,   9.99999843e-01],
#        [  9.17599173e-04,   9.99999579e-01],
#        [  1.40529737e-03,   9.99999013e-01],
#        [  7.04618623e-04,   9.99999752e-01],
#        [  1.17146353e-03,   9.99999314e-01],
#        [  1.06870168e-03,   9.99999429e-01],
#        [  6.66223096e-04,   9.99999778e-01],
#        [  5.88513880e-04,   9.99999827e-01],
#        [  9.95392156e-04,   9.99999505e-01],
#        [  1.17402746e-03,   9.99999311e-01],
#        [  1.17234022e-03,   9.99999313e-01],
#        [  4.07890516e-04,   9.99999917e-01],
#        [  1.25052478e-03,   9.99999218e-01],
#        [  0.00000000e+00,   1.00000000e+00],
#        [  1.29480628e-03,   9.99999162e-01],
#        [  8.44945994e-04,   9.99999643e-01],
#        [  6.31566954e-04,   9.99999801e-01],
#        [  5.97972397e-04,   9.99999821e-01],
#        [  8.47108689e-04,   9.99999641e-01],
#        [  3.46379627e-04,   9.99999940e-01],
#        [  1.58513198e-03,   9.99998744e-01],
#        [  9.78825325e-04,   9.99999521e-01],
#        [  1.18361499e-03,   9.99999300e-01],
#        [  1.51534914e-03,   9.99998852e-01],
#        [  6.47473820e-04,   9.99999790e-01],
#        [  9.72250771e-04,   9.99999527e-01],
#        [  9.39764771e-04,   9.99999558e-01],
#        [  4.40235029e-04,   9.99999903e-01],
#        [  4.41038344e-04,   9.99999903e-01],
#        [  6.83092357e-04,   9.99999767e-01],
#        [  8.59232835e-04,   9.99999631e-01],
#        [  8.46635641e-04,   9.99999642e-01],
#        [  0.00000000e+00,   1.00000000e+00],
#        [  6.40549233e-04,   9.99999795e-01],
#        [  1.30584740e-03,   9.99999147e-01],
#        [  1.71254810e-03,   9.99998534e-01],
#        [  1.21739040e-03,   9.99999259e-01],
#        [  6.69489436e-04,   9.99999776e-01],
#        [  9.57894297e-04,   9.99999541e-01],
#        [  1.06861641e-03,   9.99999429e-01],
#        [  6.90228735e-04,   9.99999762e-01],
#        [  5.74322833e-04,   9.99999835e-01],
#        [  9.48734593e-04,   9.99999550e-01],
#        [  5.24213860e-04,   9.99999863e-01],
#        [  1.68375003e-03,   9.99998582e-01],
#        [  6.07199130e-04,   9.99999816e-01],
#        [  1.57901530e-03,   9.99998753e-01],
#        [  8.07942771e-04,   9.99999674e-01],
#        [  7.39257779e-04,   9.99999727e-01],
#        [  8.21890020e-04,   9.99999662e-01],
#        [  1.26929880e-03,   9.99999194e-01],
#        [  1.30388868e-03,   9.99999150e-01],
#        [  7.28526731e-04,   9.99999735e-01],
#        [  5.56584574e-04,   9.99999845e-01],
#        [  1.72509173e-03,   9.99998512e-01],
#        [  2.60442123e-03,   9.99996608e-01],
#        [  9.70462218e-04,   9.99999529e-01],
#        [  1.27583695e-03,   9.99999186e-01],
#        [  9.84600972e-04,   9.99999515e-01],
#        [  2.20669397e-03,   9.99997565e-01],
#        [  4.47698196e-04,   9.99999900e-01],
#        [  1.87748957e-03,   9.99998238e-01],
#        [  5.93535297e-04,   9.99999824e-01],
#        [  7.01246710e-04,   9.99999754e-01],
#        [  8.93629823e-04,   9.99999601e-01],
#        [  8.60510062e-04,   9.99999630e-01],
#        [  0.00000000e+00,   1.00000000e+00],
#        [  1.04777813e-03,   9.99999451e-01],
#        [  9.13841426e-04,   9.99999582e-01],
#        [  1.45615360e-03,   9.99998940e-01],
#        [  1.47654367e-03,   9.99998910e-01],
#        [  8.92435542e-04,   9.99999602e-01],
#        [  1.25271051e-03,   9.99999215e-01],
#        [  1.10817704e-03,   9.99999386e-01],
#        [  1.36480166e-03,   9.99999069e-01],
#        [  1.00241846e-03,   9.99999498e-01],
#        [  1.43461013e-03,   9.99998971e-01],
#        [  2.21142477e-03,   9.99997555e-01],
#        [  1.03750101e-03,   9.99999462e-01],
#        [  1.21095629e-03,   9.99999267e-01],
#        [  8.51134054e-04,   9.99999638e-01],
#        [  4.45791682e-04,   9.99999901e-01],
#        [  1.34990184e-03,   9.99999089e-01],
#        [  7.71028349e-04,   9.99999703e-01],
#        [  9.65332289e-04,   9.99999534e-01],
#        [  1.38757263e-03,   9.99999037e-01],
#        [  3.34786258e-04,   9.99999944e-01],
#        [  9.17182277e-04,   9.99999579e-01],
#        [  1.04278323e-03,   9.99999456e-01],
#        [  9.40756110e-04,   9.99999557e-01],
#        [  6.71010990e-04,   9.99999775e-01],
#        [  6.86331339e-04,   9.99999764e-01],
#        [  2.26960778e-04,   9.99999974e-01],
#        [  1.73858979e-03,   9.99998489e-01],
#        [  7.78412733e-04,   9.99999697e-01],
#        [  6.35832059e-04,   9.99999798e-01],
#        [  9.02889324e-04,   9.99999592e-01],
#        [  1.24526582e-03,   9.99999225e-01],
#        [  1.12517896e-03,   9.99999367e-01],
#        [  1.41863876e-03,   9.99998994e-01],
#        [  1.29472931e-03,   9.99999162e-01],
#        [  7.37729348e-04,   9.99999728e-01],
#        [  1.24157208e-03,   9.99999229e-01],
#        [  1.21956766e-03,   9.99999256e-01],
#        [  1.88320660e-04,   9.99999982e-01],
#        [  1.10804863e-03,   9.99999386e-01],
#        [  1.15153712e-03,   9.99999337e-01],
#        [  8.41362804e-04,   9.99999646e-01],
#        [  6.93239208e-04,   9.99999760e-01],
#        [  1.01251864e-03,   9.99999487e-01],
#        [  1.60653298e-03,   9.99998710e-01],
#        [  3.03433103e-04,   9.99999954e-01],
#        [  9.71088977e-04,   9.99999528e-01],
#        [  2.28078812e-04,   9.99999974e-01],
#        [  1.02644177e-03,   9.99999473e-01],
#        [  1.66860741e-03,   9.99998608e-01],
#        [  2.02871333e-03,   9.99997942e-01],
#        [  7.80651103e-04,   9.99999695e-01],
#        [  7.84780337e-04,   9.99999692e-01],
#        [  5.95304189e-04,   9.99999823e-01],
#        [  1.20191802e-03,   9.99999278e-01],
#        [  1.18774235e-03,   9.99999295e-01],
#        [  1.20320769e-03,   9.99999276e-01],
#        [  7.16094289e-04,   9.99999744e-01],
#        [  1.04147314e-03,   9.99999458e-01],
#        [  1.46317124e-03,   9.99998930e-01],
#        [  1.33853031e-03,   9.99999104e-01],
#        [  3.46025266e-04,   9.99999940e-01],
#        [  6.09812201e-04,   9.99999814e-01],
#        [  1.06118361e-03,   9.99999437e-01],
#        [  1.08357968e-03,   9.99999413e-01],
#        [  1.48835452e-03,   9.99998892e-01],
#        [  1.24267455e-03,   9.99999228e-01],
#        [  7.95753034e-04,   9.99999683e-01],
#        [  1.54406596e-03,   9.99998808e-01],
#        [  1.56925581e-03,   9.99998769e-01],
#        [  5.62981334e-04,   9.99999842e-01],
#        [  1.10610012e-03,   9.99999388e-01],
#        [  1.09491250e-03,   9.99999401e-01],
#        [  1.17549816e-03,   9.99999309e-01],
#        [  9.12280322e-04,   9.99999584e-01],
#        [  1.37190629e-03,   9.99999059e-01],
#        [  5.73594803e-04,   9.99999835e-01],
#        [  5.08873314e-04,   9.99999871e-01],
#        [  7.82583492e-04,   9.99999694e-01],
#        [  1.17474105e-03,   9.99999310e-01],
#        [  1.34779216e-03,   9.99999092e-01],
#        [  9.80754525e-04,   9.99999519e-01],
#        [  9.01775438e-04,   9.99999593e-01],
#        [  1.16476047e-03,   9.99999322e-01],
#        [  9.84182300e-04,   9.99999516e-01],
#        [  4.92589742e-04,   9.99999879e-01],
#        [  9.35220909e-04,   9.99999563e-01],
#        [  1.17999918e-03,   9.99999304e-01],
#        [  1.33517181e-03,   9.99999109e-01],
#        [  5.83746184e-04,   9.99999830e-01],
#        [  6.04045511e-04,   9.99999818e-01],
#        [  7.16399184e-04,   9.99999743e-01],
#        [  8.36487306e-04,   9.99999650e-01],
#        [  1.04864034e-03,   9.99999450e-01],
#        [  1.26618604e-03,   9.99999198e-01],
#        [  1.40654066e-03,   9.99999011e-01],
#        [  4.60207564e-04,   9.99999894e-01],
#        [  1.02235318e-03,   9.99999477e-01],
#        [  5.48523124e-04,   9.99999850e-01],
#        [  9.52996184e-04,   9.99999546e-01],
#        [  0.00000000e+00,   1.00000000e+00],
#        [  1.35657589e-03,   9.99999080e-01],
#        [  3.20403733e-04,   9.99999949e-01],
#        [  9.60663355e-04,   9.99999539e-01],
#        [  2.71739120e-04,   9.99999963e-01],
#        [  1.02950696e-03,   9.99999470e-01],
#        [  1.27361460e-03,   9.99999189e-01],
#        [  1.26046742e-03,   9.99999206e-01],
#        [  8.08727684e-04,   9.99999673e-01],
#        [  7.11153964e-04,   9.99999747e-01],
#        [  7.36462251e-04,   9.99999729e-01],
#        [  1.71328907e-03,   9.99998532e-01],
#        [  3.82712874e-04,   9.99999927e-01],
#        [  8.27849842e-04,   9.99999657e-01],
#        [  1.06973906e-03,   9.99999428e-01],
#        [  4.06436334e-04,   9.99999917e-01],
#        [  1.91477887e-03,   9.99998167e-01],
#        [  9.79157766e-04,   9.99999521e-01],
#        [  1.03835369e-03,   9.99999461e-01],
#        [  3.84927160e-04,   9.99999926e-01],
#        [  1.09544593e-03,   9.99999400e-01],
#        [  8.21862071e-04,   9.99999662e-01],
#        [  1.17318830e-03,   9.99999312e-01],
#        [  1.02524544e-04,   9.99999995e-01],
#        [  8.78363493e-04,   9.99999614e-01],
#        [  1.54742869e-03,   9.99998803e-01],
#        [  9.86675537e-04,   9.99999513e-01],
#        [  7.94397704e-04,   9.99999684e-01],
#        [  1.31283309e-03,   9.99999138e-01],
#        [  1.20209887e-03,   9.99999277e-01],
#        [  7.84513451e-04,   9.99999692e-01],
#        [  1.52322098e-03,   9.99998840e-01],
#        [  8.11185202e-04,   9.99999671e-01],
#        [  1.40837557e-03,   9.99999008e-01],
#        [  1.36485294e-03,   9.99999069e-01],
#        [  1.07884300e-03,   9.99999418e-01],
#        [  1.39742865e-03,   9.99999024e-01],
#        [  1.12859124e-03,   9.99999363e-01],
#        [  1.02410661e-03,   9.99999476e-01],
#        [  5.06340399e-04,   9.99999872e-01],
#        [  1.16479816e-03,   9.99999322e-01],
#        [  1.35805118e-03,   9.99999078e-01],
#        [  1.35565850e-03,   9.99999081e-01],
#        [  1.07979700e-03,   9.99999417e-01],
#        [  7.74497711e-04,   9.99999700e-01],
#        [  1.13376385e-03,   9.99999357e-01],
#        [  5.43275216e-04,   9.99999852e-01],
#        [  8.87511214e-04,   9.99999606e-01],
#        [  8.99109429e-04,   9.99999596e-01],
#        [  1.07921605e-03,   9.99999418e-01],
#        [  1.00768687e-03,   9.99999492e-01],
#        [  8.93629951e-04,   9.99999601e-01],
#        [  9.79916648e-04,   9.99999520e-01],
#        [  1.04343664e-03,   9.99999456e-01],
#        [  1.78810434e-03,   9.99998401e-01],
#        [  3.51567972e-04,   9.99999938e-01],
#        [  1.05001133e-04,   9.99999994e-01],
#        [  1.45372492e-03,   9.99998943e-01],
#        [  1.63265089e-03,   9.99998667e-01],
#        [  1.34470653e-03,   9.99999096e-01],
#        [  1.83771992e-03,   9.99998311e-01],
#        [  8.33034893e-04,   9.99999653e-01],
#        [  1.49260917e-03,   9.99998886e-01],
#        [  1.47768868e-03,   9.99998908e-01],
#        [  7.29584607e-04,   9.99999734e-01],
#        [  9.14461699e-04,   9.99999582e-01],
#        [  1.22562753e-03,   9.99999249e-01],
#        [  9.50075925e-04,   9.99999549e-01],
#        [  1.06767350e-03,   9.99999430e-01],
#        [  1.08678547e-03,   9.99999409e-01],
#        [  1.29019911e-03,   9.99999168e-01],
#        [  1.97368037e-03,   9.99998052e-01],
#        [  1.09023876e-03,   9.99999406e-01],
#        [  6.07594825e-04,   9.99999815e-01],
#        [  1.10361427e-03,   9.99999391e-01],
#        [  9.12790317e-04,   9.99999583e-01],
#        [  6.66578556e-04,   9.99999778e-01],
#        [  9.94853710e-04,   9.99999505e-01],
#        [  1.01844209e-03,   9.99999481e-01],
#        [  1.18905445e-03,   9.99999293e-01],
#        [  1.58428920e-03,   9.99998745e-01],
#        [  4.47631280e-04,   9.99999900e-01],
#        [  9.74115155e-04,   9.99999526e-01],
#        [  2.03112421e-03,   9.99997937e-01],
#        [  1.35708913e-03,   9.99999079e-01],
#        [  1.35836921e-03,   9.99999077e-01],
#        [  6.33729138e-04,   9.99999799e-01],
#        [  3.37926014e-04,   9.99999943e-01],
#        [  1.17200137e-03,   9.99999313e-01],
#        [  9.47114960e-04,   9.99999551e-01],
#        [  1.06504586e-03,   9.99999433e-01],
#        [  9.05777298e-04,   9.99999590e-01],
#        [  1.90486546e-03,   9.99998186e-01],
#        [  1.04559401e-03,   9.99999453e-01],
#        [  1.07594874e-03,   9.99999421e-01],
#        [  1.18998255e-03,   9.99999292e-01],
#        [  9.33272403e-04,   9.99999565e-01],
#        [  1.28473307e-03,   9.99999175e-01],
#        [  0.00000000e+00,   1.00000000e+00],
#        [  1.06188407e-03,   9.99999436e-01],
#        [  1.37314533e-03,   9.99999057e-01],
#        [  1.49873887e-03,   9.99998877e-01],
#        [  1.01379783e-03,   9.99999486e-01],
#        [  1.34371928e-03,   9.99999097e-01],
#        [  7.37570741e-04,   9.99999728e-01],
#        [  1.93973270e-03,   9.99998119e-01],
#        [  5.98577129e-04,   9.99999821e-01],
#        [  9.34410238e-04,   9.99999563e-01],
#        [  1.53488191e-03,   9.99998822e-01],
#        [  1.15721723e-03,   9.99999330e-01],
#        [  2.02940759e-03,   9.99997941e-01],
#        [  1.13995411e-03,   9.99999350e-01],
#        [  1.08487741e-03,   9.99999412e-01],
#        [  2.75064347e-03,   9.99996217e-01],
#        [  1.30182311e-03,   9.99999153e-01],
#        [  3.21960579e-04,   9.99999948e-01],
#        [  1.32018446e-03,   9.99999129e-01],
#        [  1.07101062e-03,   9.99999426e-01],
#        [  1.01585797e-03,   9.99999484e-01],
#        [  7.52479768e-04,   9.99999717e-01],
#        [  3.70777665e-04,   9.99999931e-01],
#        [  1.27125906e-03,   9.99999192e-01],
#        [  1.25873687e-03,   9.99999208e-01],
#        [  8.43076623e-04,   9.99999645e-01],
#        [  8.46153543e-04,   9.99999642e-01],
#        [  6.16119666e-04,   9.99999810e-01],
#        [  1.51880921e-03,   9.99998847e-01],
#        [  7.87295232e-04,   9.99999690e-01],
#        [  1.04590761e-03,   9.99999453e-01],
#        [  1.04498351e-03,   9.99999454e-01],
#        [  8.02874909e-04,   9.99999678e-01],
#        [  1.11917846e-03,   9.99999374e-01],
#        [  9.22554723e-04,   9.99999574e-01],
#        [  5.09747572e-04,   9.99999870e-01],
#        [  1.12403536e-03,   9.99999368e-01],
#        [  9.47692203e-04,   9.99999551e-01],
#        [  1.42282053e-03,   9.99998988e-01],
#        [  1.38996282e-03,   9.99999034e-01],
#        [  1.21214099e-03,   9.99999265e-01],
#        [  1.31918541e-03,   9.99999130e-01],
#        [  4.73607374e-04,   9.99999888e-01],
#        [  7.84573013e-04,   9.99999692e-01],
#        [  1.66541122e-03,   9.99998613e-01],
#        [  1.19446837e-03,   9.99999287e-01],
#        [  3.75904614e-04,   9.99999929e-01],
#        [  1.59461397e-03,   9.99998729e-01],
#        [  1.86653810e-03,   9.99998258e-01],
#        [  1.28521021e-03,   9.99999174e-01],
#        [  1.17128383e-03,   9.99999314e-01],
#        [  8.50551924e-04,   9.99999638e-01],
#        [  7.24831230e-04,   9.99999737e-01],
#        [  1.06372072e-03,   9.99999434e-01],
#        [  1.40467081e-03,   9.99999013e-01],
#        [  1.23588248e-03,   9.99999236e-01],
#        [  8.94371730e-04,   9.99999600e-01],
#        [  1.07520130e-03,   9.99999422e-01],
#        [  1.34499878e-03,   9.99999095e-01],
#        [  1.37302196e-03,   9.99999057e-01],
#        [  1.03211407e-03,   9.99999467e-01],
#        [  5.74693092e-04,   9.99999835e-01],
#        [  4.83243831e-04,   9.99999883e-01],
#        [  9.99106644e-04,   9.99999501e-01],
#        [  3.29545437e-04,   9.99999946e-01],
#        [  4.55247795e-04,   9.99999896e-01],
#        [  7.57673450e-04,   9.99999713e-01],
#        [  6.24898059e-04,   9.99999805e-01],
#        [  1.41931739e-03,   9.99998993e-01],
#        [  1.29066559e-03,   9.99999167e-01],
#        [  7.30864280e-04,   9.99999733e-01],
#        [  1.48442994e-03,   9.99998898e-01],
#        [  6.23061104e-04,   9.99999806e-01],
#        [  5.55683700e-04,   9.99999846e-01],
#        [  1.04945233e-03,   9.99999449e-01],
#        [  1.29969121e-03,   9.99999155e-01],
#        [  1.23116134e-04,   9.99999992e-01],
#        [  9.86134702e-04,   9.99999514e-01],
#        [  1.56883411e-03,   9.99998769e-01],
#        [  9.56087387e-04,   9.99999543e-01],
#        [  5.80450475e-04,   9.99999832e-01],
#        [  7.15272491e-04,   9.99999744e-01],
#        [  8.89550880e-04,   9.99999604e-01],
#        [  1.43595707e-04,   9.99999990e-01],
#        [  5.36051136e-04,   9.99999856e-01],
#        [  1.32974442e-03,   9.99999116e-01],
#        [  1.18693201e-03,   9.99999296e-01],
#        [  6.56254776e-04,   9.99999785e-01],
#        [  1.43083610e-03,   9.99998976e-01],
#        [  2.31462080e-04,   9.99999973e-01],
#        [  8.95928728e-04,   9.99999599e-01],
#        [  1.42922228e-03,   9.99998979e-01],
#        [  1.29256960e-03,   9.99999165e-01],
#        [  1.27926645e-03,   9.99999182e-01],
#        [  6.50230480e-04,   9.99999789e-01],
#        [  1.59372284e-03,   9.99998730e-01],
#        [  1.54086774e-03,   9.99998813e-01],
#        [  1.17046501e-03,   9.99999315e-01],
#        [  1.15130598e-03,   9.99999337e-01],
#        [  7.57935051e-04,   9.99999713e-01],
#        [  7.65025352e-04,   9.99999707e-01],
#        [  1.42439336e-03,   9.99998986e-01],
#        [  3.52922468e-04,   9.99999938e-01],
#        [  1.60403657e-03,   9.99998714e-01],
#        [  8.78576157e-04,   9.99999614e-01]])

# %%
conn._val_to_rgb(0.1)
# Out:
# val: 0.1
# [255, 153, 0]
